# %%
import csv
import matplotlib.pyplot as plt
import pandas as pd
import statistics
import numpy as np

# %%
import os
import glob
os.chdir("C:/Users/patpa/University/MAST30034/Assignment 2/tripdata/sample/prefinal/final")

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv("2015.csv", index=False, encoding='utf-8-sig')
# Out:
# C:\Users\patpa\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
def readcsv2():
    file_list2 = []
    f2 = open("yellow_tripdata_2015-12.csv")
    my_csv2 = csv.reader(f2)
    for row in my_csv2:
        file_list2.append(row)
    return file_list2

file_list2 = readcsv2()
print(file_list2)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
file1 = pd.read_csv("yellow_tripdata_2015-01.csv")
file1.sample(1000000, random_state=1000).to_csv('sample1.csv')
file2 = pd.read_csv("yellow_tripdata_2015-02.csv")
file2.sample(1000000, random_state=1000).to_csv('sample2.csv')
file3 = pd.read_csv("yellow_tripdata_2015-03.csv")
file3.sample(1000000, random_state=1000).to_csv('sample3.csv')
file4 = pd.read_csv("yellow_tripdata_2015-04.csv")
file4.sample(1000000, random_state=1000).to_csv('sample4.csv')
file5 = pd.read_csv("yellow_tripdata_2015-05.csv")
file5.sample(1000000, random_state=1000).to_csv('sample5.csv')
file6 = pd.read_csv("yellow_tripdata_2015-06.csv")
file6.sample(1000000, random_state=1000).to_csv('sample6.csv')
file7 = pd.read_csv("yellow_tripdata_2015-07.csv")
file7.sample(1000000, random_state=1000).to_csv('sample7.csv')
file8 = pd.read_csv("yellow_tripdata_2015-08.csv")
file8.sample(1000000, random_state=1000).to_csv('sample8.csv')
file9 = pd.read_csv("yellow_tripdata_2015-09.csv")
file9.sample(1000000, random_state=1000).to_csv('sample9.csv')
file10 = pd.read_csv("yellow_tripdata_2015-10.csv")
file10.sample(1000000, random_state=1000).to_csv('sample10.csv')
file11 = pd.read_csv("yellow_tripdata_2015-11.csv")
file11.sample(1000000, random_state=1000).to_csv('sample11.csv')
file12 = pd.read_csv("yellow_tripdata_2015-12.csv")
file12.sample(1000000, random_state=1000).to_csv('sample12.csv')

# %%
len(file1) + len(file2) + len(file3) + len(file4) + len(file5) + len(file6) + len(file7) + len(file8) + len(file9) + len(file10) + len(file11) + len(file12)

# %%
file2015 = pd.read_csv("2015.csv")
# Out:
#          Duration  RateCodeID  RatecodeID  Unemployment_rate  VendorID  \
# 0        0.009884         NaN         1.0               5.14         1
# 1        0.019109         NaN         1.0               5.14         1
# 2        0.005625         NaN         1.0               5.14         2
# 3        0.003021         NaN         1.0               5.14         1
# 4        0.006725         NaN         1.0               5.14         1
# 5        0.044236         NaN         1.0               5.14         2
# 6        0.008981         NaN         1.0               5.14         1
# 7        0.013831         NaN         1.0               5.14         2
# 8        0.002523         NaN         1.0               5.14         2
# 9        0.005613         NaN         1.0               5.14         1
# 10       0.004167         NaN         1.0               5.14         2
# 11       0.021215         NaN         1.0               5.14         1
# ...

# %%
def readcsv():
    file_list = []
    f = open("2015.csv")
    my_csv = csv.reader(f)
    for row in my_csv:
        file_list.append(row)
    return file_list

file_list = readcsv()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(file_list[2][0])
type(file_list[2][0])
# Out:
# 0.019108796
# str

# %%
finallist = []
dummy = 0
for i in file_list:
    if dummy == 0:
        dummy += 1
        pass
    else:
        if (float(i[0]) > 0) :
            finallist.append(i)

print(finallist)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
with open('filename', 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    wr.writerow(finallist)

# %%
file1 = pd.read_csv("1.csv")

# %%
file2 = pd.read_csv("2.csv")

# %%
file3 = pd.read_csv("3.csv")

# %%
file4 = pd.read_csv("4.csv")

# %%
file5 = pd.read_csv("5.csv")

# %%
file6= pd.read_csv("6.csv")

# %%
file7 = pd.read_csv("7.csv")

# %%
file8 = pd.read_csv("8.csv")

# %%
file9 = pd.read_csv("9.csv")

# %%
file10 = pd.read_csv("10.csv")

# %%
file11 = pd.read_csv("11.csv")

# %%
file12 = pd.read_csv("12.csv")

# %%
tip1 = statistics.mean(file1["tip_amount"])
tip2 = statistics.mean(file2["tip_amount"])
tip3 = statistics.mean(file3["tip_amount"])
tip4 = statistics.mean(file4["tip_amount"])
tip5 = statistics.mean(file5["tip_amount"])
tip6 = statistics.mean(file6["tip_amount"])
tip7 = statistics.mean(file7["tip_amount"])
tip8 = statistics.mean(file8["tip_amount"])
tip9 = statistics.mean(file9["tip_amount"])
tip10 = statistics.mean(file10["tip_amount"])
tip11 = statistics.mean(file11["tip_amount"])
tip12 = statistics.mean(file12["tip_amount"])

# %%
tiplist = [tip1, tip2, tip3, tip4, tip5, tip6, tip7, tip8, tip9, tip10, tip11, tip12]
tiplist
# Out:
# [2.726723101532107,
#  2.5550990627082157,
#  2.630929309465574,
#  2.665580102995642,
#  2.7333768553629247,
#  2.7202812569275103,
#  2.672782370600944,
#  2.6629694206008585,
#  2.723424328915739,
#  2.739734686127504,
#  2.7220748727106314,
#  2.7272143226135515]

# %%
for i in file1:
    print(i)
# Out:
# VendorID
# tpep_pickup_datetime
# tpep_dropoff_datetime
# passenger_count
# trip_distance
# pickup_longitude
# pickup_latitude
# RatecodeID
# store_and_fwd_flag
# dropoff_longitude
# dropoff_latitude
# payment_type
# fare_amount
# extra
# mta_tax
# tip_amount
# tolls_amount
# improvement_surcharge
# total_amount
# Duration
# Unemployment_rate

# %%
unemp1 = file1["Unemployment_rate"][0]
unemp2 = file2["Unemployment_rate"][0]
unemp3 = file3["Unemployment_rate"][0]
unemp4 = file4["Unemployment_rate"][0]
unemp5 = file5["Unemployment_rate"][0]
unemp6 = file6["Unemployment_rate"][0]
unemp7 = file7["Unemployment_rate"][0]
unemp8 = file8["Unemployment_rate"][0]
unemp9 = file9["Unemployment_rate"][0]
unemp10 = file10["Unemployment_rate"][0]
unemp11 = file11["Unemployment_rate"][0]
unemp12 = file12["Unemployment_rate"][0]
unemplist = [unemp1, unemp2, unemp3, unemp4, unemp5, unemp6, unemp6, unemp7, unemp8, unemp9, unemp10, unemp11, unemp12]
unemplist
# Out:
# [5.14, 6.62, 6, 5.64, 5.77, 5.6, 5.6, 5.78, 5.44, 4.98, 5.23, 5.23, 5.14]

# %%
fare1 = statistics.mean(file1["fare_amount"])
fare2 = statistics.mean(file2["fare_amount"])
fare3 = statistics.mean(file3["fare_amount"])
fare4 = statistics.mean(file4["fare_amount"])
fare5 = statistics.mean(file5["fare_amount"])
fare6 = statistics.mean(file6["fare_amount"])
fare7 = statistics.mean(file7["fare_amount"])
fare8 = statistics.mean(file8["fare_amount"])
fare9 = statistics.mean(file9["fare_amount"])
fare10 = statistics.mean(file10["fare_amount"])
fare11 = statistics.mean(file11["fare_amount"])
fare12 = statistics.mean(file12["fare_amount"])

# %%
one = [tip1, fare1]
two = [tip2, fare2]
three = [tip3, fare3]
four = [tip4, fare4]
five = [tip5, fare5]
six = [tip6, fare6]
seven = [tip7, fare7]
eight = [tip8, fare8]
nine = [tip9, fare9]
ten = [tip10, fare10]
eleven = [tip11, fare11]
twelve = [tip12, fare12]

# %%
one = [tip1, unemp1]
two = [tip2, unemp2]
three = [tip3, unemp3]
four = [tip4, unemp4]
five = [tip5, unemp5]
six = [tip6, unemp6]
seven = [tip7, unemp7]
eight = [tip8, unemp8]
nine = [tip9, unemp9]
ten = [tip10, unemp10]
eleven = [tip11, unemp11]
twelve = [tip12, unemp12]

# %%
df = pd.DataFrame([one, two, three, four, five, six, seven, eight, nine, ten, eleven, twelve])
x_labels = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
ax = df.plot(kind='bar')
ax.set_xticklabels(x_labels)
ax.legend(["Tip amount ($)", "Unemployment Rate (%)"], loc='upper center', bbox_to_anchor=(0.5, 1.1),
          ncol=3, shadow=True)
plt.xlabel('Month', fontsize=16)
plt.ylabel('Quantity', fontsize=16)
from matplotlib.pyplot import figure
figure(num=None, figsize=(10, 8), dpi=800, facecolor='w', edgecolor='k')

# %%
df = pd.DataFrame([one, two, three, four, five, six, seven, eight, nine, ten, eleven, twelve])
x_labels = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
ax = df.plot(kind='bar')
ax.set_xticklabels(x_labels)
ax.legend(["Tip amount ($)", "Fare amount ($)"], loc='upper center', bbox_to_anchor=(0.5, 1.1),
          ncol=3, shadow=True)
plt.xlabel('Month', fontsize=16)
plt.ylabel('Quantity', fontsize=16)
from matplotlib.pyplot import figure
figure(num=None, figsize=(10, 8), dpi=800, facecolor='r', edgecolor='k')

# %%
alltiplist = []
for i in file1["tip_amount"]:
    alltiplist.append(i)
for i in file2["tip_amount"]:
    alltiplist.append(i)
for i in file3["tip_amount"]:
    alltiplist.append(i)
for i in file4["tip_amount"]:
    alltiplist.append(i)xla
for i in file5["tip_amount"]:
    alltiplist.append(i)
for i in file6["tip_amount"]:
    alltiplist.append(i)
for i in file7["tip_amount"]:
    alltiplist.append(i)
for i in file8["tip_amount"]:
    alltiplist.append(i)
for i in file9["tip_amount"]:
    alltiplist.append(i)
for i in file10["tip_amount"]:
    alltiplist.append(i)
for i in file11["tip_amount"]:
    alltiplist.append(i)
for i in file12["tip_amount"]:
    alltiplist.append(i)

# %%
import seaborn as sns
sns.distplot(alltiplist, hist=False, kde=True,
             color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
plt.xlabel("Tip amount ($)")
plt.ylabel("Density")
# Out:
# Text(0, 0.5, 'Density')

# %%
import scipy.stats as stats
alltiplistdf = pd.DataFrame([alltiplist])
alltiplistdf.kurt()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-f26a7acd61e7> in <module>
#       1 import scipy.stats as stats
#       2 alltiplistdf = pd.DataFrame([alltiplist])
# ----> 3 alltiplist.kurt()
#
# AttributeError: 'list' object has no attribute 'kurt'

# %%
alltiplistdf.skew()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-a7ba86fea969> in <module>
# ----> 1 alltiplist.skew()
#
# AttributeError: 'list' object has no attribute 'skew'
